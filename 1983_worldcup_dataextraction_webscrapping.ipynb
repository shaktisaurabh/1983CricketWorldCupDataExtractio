# %%
import requests 
import pandas as pd
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
url="https://en.wikipedia.org/wiki/1983_Cricket_World_Cup"

# %%
res=requests.get(url,headers=headers).text
soup=BeautifulSoup(res,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>1983 Cricket World Cup - Wikipedia</title>
# ...

# %%
target_div=soup.find_all('div',style='text-align:right')
date_of_match=[]
for ch in target_div:
    date_of_match.append(ch.text)
# print(date_of_match)
def conda1(amb):
    amb=amb.replace('Scorecard','')
    amb=amb.replace('scorecard','')
    return amb
date_of_match=list(map(conda1,date_of_match))
print(date_of_match)
# Out:
# ['9 June 1983 ', '9 June 1983 ', '11 June 1983 ', '11 June 1983 ', '13 June 1983 ', '13 June 1983 ', '15 June 1983 ', '16 June 1983 ', '18 June 1983 ', '18 June 1983 ', '20 June 1983 ', '20 June 1983 ', '9 June 1983 ', '9 June 1983 ', '11 June 1983 ', '11 June 1983 ', '13 June 1983 ', '13 June 1983 ', '15 June 1983 ', '16 June 1983 ', '18 June 1983 ', '18 June 1983 ', '20 June 1983 ', '20 June 1983 ', '22 June 1983 ', '22 June 1983 ', '25 June 1983 ']

# %%
print(date_of_match)
#
# Out:
# ['9 June 1983 ', '9 June 1983 ', '11 June 1983 ', '11 June 1983 ', '13 June 1983 ', '13 June 1983 ', '15 June 1983 ', '16 June 1983 ', '18 June 1983 ', '18 June 1983 ', '20 June 1983 ', '20 June 1983 ', '9 June 1983 ', '9 June 1983 ', '11 June 1983 ', '11 June 1983 ', '13 June 1983 ', '13 June 1983 ', '15 June 1983 ', '16 June 1983 ', '18 June 1983 ', '18 June 1983 ', '20 June 1983 ', '20 June 1983 ', '22 June 1983 ', '22 June 1983 ', '25 June 1983 ']

# %%
#tag.next_sibling refers to the next element after the tag and tag.next_sibling.strip() strips whitespaces, newlines and tabs at
#the start and end of the next_sibling text.

# %%
import re
teams=[]
soup.find_all('a',title=re.compile(r"^[a-zA-Z\s]+cricket team\b")
# Out:
#   File "C:\Users\LENOVO\AppData\Local\Temp\ipykernel_9740\2426682347.py", line 3
#     soup.find_all('a',title=re.compile(r"^[a-zA-Z\s]+cricket team\b")
#                                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
import re


# Adding the missing parenthesis after find_all() call
teams = soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))

print(teams)
# Out:
# [<div style="width: 100%; background-color: inherit; color:inherit">
# <table style="float:left; width:15%; table-layout:fixed">
# <tbody><tr>
# <td><div style="text-align:right">9 June 1983 <br/><small><a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65064.html" rel="nofollow">Scorecard</a></small></div>
# </td></tr></tbody></table>
# <table style="float:left; width:53%; table-layout:fixed; text-align:center">
# <tbody><tr style="vertical-align:top">
# ...

# %%
teamo=[]
for div in teams:
    teamo.append(div.find('a'))
print(teamo)
# Out:
# [<a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65064.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65065.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65068.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65069.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65072.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65073.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65076.html" rel="nofollow">Scorecard</a>, <a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65078.html" rel="nofollow">Scorecard</a>, <a class="external text" href
# ...

# %%
import re

# Sample text
text = "Hello World! 2Welcome to OpenAI 2024."

# Compile the regex pattern
pattern = re.compile(r'[a-zA-Z\s]+')

# Find all matches in the text
matches = pattern.findall(text)

print(matches)
# Out:
# ['Hello World', ' ', 'Welcome to OpenAI ']

# %%
import re
res=requests.get(url,headers=headers).text
soup=BeautifulSoup(res,'lxml')
teams = soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
a_tags1=[]
for div in teams:
    a_tags=div.find_all('a',title=re.compile(r"^[a-zA-Z\s]+cricket team\b"))
    a_tags1.extend(a_tags)
print(a_tags1)
# Out:
# [<a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/New_Zealand_national_cricket_team" title="New Zealand national cricket team">New Zealand</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/Sri_Lanka_national_cricket_team" title="Sri Lanka national cricket team">Sri Lanka</a>, <a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/Sri_Lanka_national_cricket_team" title="Sri Lanka national cricket team">Sri Lanka</a>, <a href="/wiki/New_Zealand_national_cricket_team" title="New Zealand national cricket team">New Zealand</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/Sri_Lanka_national_cr
# ...

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
a_tag=[]
for tag in teamo:
    an=tag.find_all('a',title=re.compile(r"^[a-zA-Z\s]+cricket team\b")) 
    a_tag.extend(an)
print(a_tag)
# Out:
# [<a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/New_Zealand_national_cricket_team" title="New Zealand national cricket team">New Zealand</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/Sri_Lanka_national_cricket_team" title="Sri Lanka national cricket team">Sri Lanka</a>, <a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/Sri_Lanka_national_cricket_team" title="Sri Lanka national cricket team">Sri Lanka</a>, <a href="/wiki/New_Zealand_national_cricket_team" title="New Zealand national cricket team">New Zealand</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/Sri_Lanka_national_cr
# ...

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
all_teams=[]
for tag in teamo:
    an=tag.find_all('a',title=re.compile(r"^[a-zA-Z\s]+cricket team\b"))
    all_teams.extend(an)
print(all_teams)
# Out:
# [<a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/New_Zealand_national_cricket_team" title="New Zealand national cricket team">New Zealand</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/Sri_Lanka_national_cricket_team" title="Sri Lanka national cricket team">Sri Lanka</a>, <a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/Sri_Lanka_national_cricket_team" title="Sri Lanka national cricket team">Sri Lanka</a>, <a href="/wiki/New_Zealand_national_cricket_team" title="New Zealand national cricket team">New Zealand</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/Pakistan_national_cricket_team" title="Pakistan national cricket team">Pakistan</a>, <a href="/wiki/England_cricket_team" title="England cricket team">England</a>, <a href="/wiki/Sri_Lanka_national_cr
# ...

# %%
#The above box is meant for finding the HTML text for all teams that were involved in the competition having a tags....after this
#we extract the text of all the teams to get a list of the teams that were involved in the competition.

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text 
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
all_res=[]
for k in teamo:
    q=k.find_all('a',title=re.compile(r"^1983 Cricket World Cup[a-zA-Z\s]+"))
    all_res.append(q)
print(all_res)
# Out:
# [[<a href="/wiki/1983_Cricket_World_Cup_Group_A#match1" title="1983 Cricket World Cup Group A">England won by 106 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match2" title="1983 Cricket World Cup Group A">Pakistan won by 50 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match5" title="1983 Cricket World Cup Group A">England won by 47 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match6" title="1983 Cricket World Cup Group A">New Zealand won by 52 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match9" title="1983 Cricket World Cup Group A">England won by 8 wickets</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match10" title="1983 Cricket World Cup Group A">New Zealand won by 5 wickets</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match13" title="1983 Cricket World Cup Group A">New Zealand won by 2 wickets</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match15" title="1983 Cricket World Cup Group A">Pakistan won by 11 
# ...

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text 
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
all_res=[]
for k in teamo:
    q=k.find_all('a',title=re.compile(r"^1983 Cricket World Cup[a-zA-Z\s]+"))
    all_res.append(q)
print(all_res)
# Out:
# [[<a href="/wiki/1983_Cricket_World_Cup_Group_A#match1" title="1983 Cricket World Cup Group A">England won by 106 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match2" title="1983 Cricket World Cup Group A">Pakistan won by 50 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match5" title="1983 Cricket World Cup Group A">England won by 47 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match6" title="1983 Cricket World Cup Group A">New Zealand won by 52 runs</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match9" title="1983 Cricket World Cup Group A">England won by 8 wickets</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match10" title="1983 Cricket World Cup Group A">New Zealand won by 5 wickets</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match13" title="1983 Cricket World Cup Group A">New Zealand won by 2 wickets</a>], [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match15" title="1983 Cricket World Cup Group A">Pakistan won by 11 
# ...

# %%
all_res_new=[a_tag for sublist in all_res for a_tag in sublist if a_tag] 
all_res_new
# Out:
# [<a href="/wiki/1983_Cricket_World_Cup_Group_A#match1" title="1983 Cricket World Cup Group A">England won by 106 runs</a>,
#  <a href="/wiki/1983_Cricket_World_Cup_Group_A#match2" title="1983 Cricket World Cup Group A">Pakistan won by 50 runs</a>,
#  <a href="/wiki/1983_Cricket_World_Cup_Group_A#match5" title="1983 Cricket World Cup Group A">England won by 47 runs</a>,
#  <a href="/wiki/1983_Cricket_World_Cup_Group_A#match6" title="1983 Cricket World Cup Group A">New Zealand won by 52 runs</a>,
#  <a href="/wiki/1983_Cricket_World_Cup_Group_A#match9" title="1983 Cricket World Cup Group A">England won by 8 wickets</a>,
#  <a href="/wiki/1983_Cricket_World_Cup_Group_A#match10" title="1983 Cricket World Cup Group A">New Zealand won by 5 wickets</a>,
#  <a href="/wiki/1983_Cricket_World_Cup_Group_A#match13" title="1983 Cricket World Cup Group A">New Zealand won by 2 wickets</a>,
# ...

# %%
results=[]
for k in all_res_new:
    results.append(k.text)
print(results)
# Out:
# ['England won by 106 runs', 'Pakistan won by 50 runs', 'England won by 47 runs', 'New Zealand won by 52 runs', 'England won by 8 wickets', 'New Zealand won by 5 wickets', 'New Zealand won by 2 wickets', 'Pakistan won by 11 runs', 'England won by 7 wickets', 'Sri Lanka won by 3 wickets', 'England won by 9 wickets', 'Pakistan won by 11 runs', 'Zimbabwe won by 13 runs', 'India won by 34 runs', 'West Indies won by 101 runs', 'India won by 5 wickets', 'Australia won by 162 runs', 'West Indies won by 8 wickets', 'West Indies won by 66 runs', 'Australia won by 32 runs', 'West Indies won by 7 wickets', 'India won by 31 runs', 'India won by 118 runs', 'West Indies won by 10 wickets', 'India won by 6 wickets', 'West Indies won by 8 wickets']

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text 
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
chc=[] 
for k in teamo:
    am=k.find_all('b')
    chc.extend(am)
chc1=chc[-1]
results.append(chc1.text)
print(results)
# Out:
# ['England won by 106 runs', 'Pakistan won by 50 runs', 'England won by 47 runs', 'New Zealand won by 52 runs', 'England won by 8 wickets', 'New Zealand won by 5 wickets', 'New Zealand won by 2 wickets', 'Pakistan won by 11 runs', 'England won by 7 wickets', 'Sri Lanka won by 3 wickets', 'England won by 9 wickets', 'Pakistan won by 11 runs', 'Zimbabwe won by 13 runs', 'India won by 34 runs', 'West Indies won by 101 runs', 'India won by 5 wickets', 'Australia won by 162 runs', 'West Indies won by 8 wickets', 'West Indies won by 66 runs', 'Australia won by 32 runs', 'West Indies won by 7 wickets', 'India won by 31 runs', 'India won by 118 runs', 'West Indies won by 10 wickets', 'India won by 6 wickets', 'West Indies won by 8 wickets', 'India won by 43 runs']

# %%
print(results)
#
# Out:
# ['England won by 106 runs', 'Pakistan won by 50 runs', 'England won by 47 runs', 'New Zealand won by 52 runs', 'England won by 8 wickets', 'New Zealand won by 5 wickets', 'New Zealand won by 2 wickets', 'Pakistan won by 11 runs', 'England won by 7 wickets', 'Sri Lanka won by 3 wickets', 'England won by 9 wickets', 'Pakistan won by 11 runs', 'Zimbabwe won by 13 runs', 'India won by 34 runs', 'West Indies won by 101 runs', 'India won by 5 wickets', 'Australia won by 162 runs', 'West Indies won by 8 wickets', 'West Indies won by 66 runs', 'Australia won by 32 runs', 'West Indies won by 7 wickets', 'India won by 31 runs', 'India won by 118 runs', 'West Indies won by 10 wickets', 'India won by 6 wickets', 'West Indies won by 8 wickets', 'India won by 43 runs']

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text 
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
venue=[]
for k in teamo:
    am=k.find_all('a',title=re.compile(r"^[a-zA-z]+(?!.*cricket team)"))
    venue.extend(am)
print(venue)
# Out:
# [<a href="/wiki/The_Oval" title="The Oval">The Oval</a>, <a href="/wiki/London" title="London">London</a>, <a class="mw-redirect" href="/wiki/St_Helens_Rugby_and_Cricket_Ground" title="St Helens Rugby and Cricket Ground">St Helen's</a>, <a href="/wiki/Swansea" title="Swansea">Swansea</a>, <a href="/wiki/County_Ground,_Taunton" title="County Ground, Taunton">County Ground</a>, <a href="/wiki/Taunton" title="Taunton">Taunton</a>, <a href="/wiki/Edgbaston_Cricket_Ground" title="Edgbaston Cricket Ground">Edgbaston</a>, <a href="/wiki/Birmingham" title="Birmingham">Birmingham</a>, <a href="/wiki/Lord%27s" title="Lord's">Lord's</a>, <a href="/wiki/London" title="London">London</a>, <a class="mw-redirect" href="/wiki/County_Cricket_Ground,_Bristol" title="County Cricket Ground, Bristol">County Ground</a>, <a href="/wiki/Bristol" title="Bristol">Bristol</a>, <a href="/wiki/Edgbaston_Cricket_Ground" title="Edgbaston Cricket Ground">Edgbaston</a>, <a href="/wiki/Birmingham" title="Birmingham">
# ...

# %%
venue1=[]
for k in venue:
    venue1.append(k.text)
print(venue1)
# Out:
# ['The Oval', 'London', "St Helen's", 'Swansea', 'County Ground', 'Taunton', 'Edgbaston', 'Birmingham', "Lord's", 'London', 'County Ground', 'Bristol', 'Edgbaston', 'Birmingham', 'Headingley', 'Leeds', 'Old Trafford', 'Manchester', 'County Ground', 'Derby', 'Headingley', 'Leeds', 'Trent Bridge', 'Nottingham', 'Trent Bridge', 'Nottingham', 'Old Trafford', 'Manchester', 'Headingley', 'Leeds', 'Grace Road', 'Leicester', 'Trent Bridge', 'Nottingham', 'New Road', 'Worcester', 'The Oval', 'London', 'County Ground', 'Southampton', "Lord's", 'London', 'Nevill Ground', 'Royal Tunbridge Wells', 'County Ground', 'Chelmsford', 'Edgbaston', 'Birmingham', 'Old Trafford', 'Manchester', 'The Oval', 'London', "Lord's", 'London']

# %%
ground=venue1[::2]
ground
#
# Out:
# ['The Oval',
#  "St Helen's",
#  'County Ground',
#  'Edgbaston',
#  "Lord's",
#  'County Ground',
#  'Edgbaston',
#  'Headingley',
#  'Old Trafford',
#  'County Ground',
#  'Headingley',
#  'Trent Bridge',
#  'Trent Bridge',
#  'Old Trafford',
#  'Headingley',
#  'Grace Road',
#  'Trent Bridge',
#  'New Road',
#  'The Oval',
#  'County Ground',
#  "Lord's",
#  'Nevill Ground',
#  'County Ground',
#  'Edgbaston',
#  'Old Trafford',
#  'The Oval',
#  "Lord's"]

# %%
location=venue1[1::2]
location
#
# Out:
# ['London',
#  'Swansea',
#  'Taunton',
#  'Birmingham',
#  'London',
#  'Bristol',
#  'Birmingham',
#  'Leeds',
#  'Manchester',
#  'Derby',
#  'Leeds',
#  'Nottingham',
#  'Nottingham',
#  'Manchester',
#  'Leeds',
#  'Leicester',
#  'Nottingham',
#  'Worcester',
#  'London',
#  'Southampton',
#  'London',
#  'Royal Tunbridge Wells',
#  'Chelmsford',
#  'Birmingham',
#  'Manchester',
#  'London',
#  'London']

# %%
import re 
import requests
from bs4 import BeautifulSoup 
res=requests.get(url,headers=headers).text 
soup=BeautifulSoup(res,'lxml')
teamo=soup.find_all('div',style=re.compile(r"^width: 100%;[\s\w;:-]+"))
score=[]
for sc in teamo:
    an=sc.find_all('br')
    for an1 in an:
        text=an1.next_sibling
        score.append(text)
print(score)
#     for an1 in an:
#         text=an1.next_sibling
#         if text and text.strip():
#             score.append(text.strip())
# print(score)
# Out:
# [<small><a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65064.html" rel="nofollow">Scorecard</a></small>, '322/6 (60 overs) ', '216 (59 overs) ', <small><a href="/wiki/The_Oval" title="The Oval">The Oval</a>, <a href="/wiki/London" title="London">London</a></small>, <small><a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65065.html" rel="nofollow">Scorecard</a></small>, '338/5 (60 overs) ', '288/9 (60 overs) ', <small><a class="mw-redirect" href="/wiki/St_Helens_Rugby_and_Cricket_Ground" title="St Helens Rugby and Cricket Ground">St Helen's</a>, <a href="/wiki/Swansea" title="Swansea">Swansea</a></small>, <small><a class="external text" href="http://content.cricinfo.com/wc1983/engine/match/65068.html" rel="nofollow">Scorecard</a></small>, '333/9 (60 overs) ', '286 (58 overs) ', <small><a href="/wiki/County_Ground,_Taunton" title="County Ground, Taunton">County Ground</a>, <a href="/wiki/Taunton" title="Taunton">Taunton</a><
# ...

# %%
all_team1=[]
for t in all_teams:
    aq=t.text
    all_team1.append(aq)
print(all_team1)
# Out:
# ['England', 'New Zealand', 'Pakistan', 'Sri Lanka', 'England', 'Sri Lanka', 'New Zealand', 'Pakistan', 'Pakistan', 'England', 'Sri Lanka', 'New Zealand', 'England', 'New Zealand', 'Pakistan', 'Sri Lanka', 'Pakistan', 'England', 'New Zealand', 'Sri Lanka', 'Sri Lanka', 'England', 'Pakistan', 'New Zealand', 'Zimbabwe', 'Australia', 'India', 'West Indies', 'West Indies', 'Australia', 'Zimbabwe', 'India', 'Australia', 'India', 'Zimbabwe', 'West Indies', 'West Indies', 'India', 'Australia', 'Zimbabwe', 'Australia', 'West Indies', 'India', 'Zimbabwe', 'India', 'Australia', 'Zimbabwe', 'West Indies', 'England', 'India', 'Pakistan', 'West Indies', 'India', 'West Indies']

# %%
teambat_first=all_team1[0::2]
teambat_first
#
# Out:
# ['England',
#  'Pakistan',
#  'England',
#  'New Zealand',
#  'Pakistan',
#  'Sri Lanka',
#  'England',
#  'Pakistan',
#  'Pakistan',
#  'New Zealand',
#  'Sri Lanka',
#  'Pakistan',
#  'Zimbabwe',
#  'India',
#  'West Indies',
#  'Zimbabwe',
#  'Australia',
#  'Zimbabwe',
#  'West Indies',
#  'Australia',
#  'Australia',
#  'India',
#  'India',
#  'Zimbabwe',
#  'England',
#  'Pakistan',
#  'India']

# %%
teambat_second=all_team1[1::2]
teambat_second
#
# Out:
# ['New Zealand',
#  'Sri Lanka',
#  'Sri Lanka',
#  'Pakistan',
#  'England',
#  'New Zealand',
#  'New Zealand',
#  'Sri Lanka',
#  'England',
#  'Sri Lanka',
#  'England',
#  'New Zealand',
#  'Australia',
#  'West Indies',
#  'Australia',
#  'India',
#  'India',
#  'West Indies',
#  'India',
#  'Zimbabwe',
#  'West Indies',
#  'Zimbabwe',
#  'Australia',
#  'West Indies',
#  'India',
#  'West Indies',
#  'West Indies']

# %%
#BeautifulSoup(res,'lxml') converts raw HTML text from webpage into a structure that python can easily navigate through

# %%
a1=[1,2,3]
a2=[4,5,6]
a3=[22]
a3.extend(a1)
print(a3)
# Out:
# [22, 1, 2, 3]

# %%
a3.extend(a2)
print(a3)
# Out:
# [22, 1, 2, 3, 4, 5, 6]

# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup

# %%
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3"
}
url="https://en.wikipedia.org/wiki/1983_Cricket_World_Cup"

# %% [markdown]
# This is my attempt to find the respective scores and the scoreboard

# %%
res=requests.get(url,headers=headers)
soup=BeautifulSoup(res.text,'lxml')
scorecard_link=[a['href'] for a in soup.find_all('a',string='Scorecard') if 'href' in a.attrs]
scorecard_link
# Out:
# ['http://content.cricinfo.com/wc1983/engine/match/65064.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65065.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65068.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65069.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65072.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65073.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65076.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65078.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65080.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65081.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65084.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65085.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65066.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65067.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65070.html',
# ...

# %%
res=requests.get(url,headers=headers) 
soup=BeautifulSoup(res.text,'lxml')
scoreboard_link1=[a['href'] for a in soup.find_all('a',string='scorecard') if 'href' in a.attrs] 
scoreboard_link1
# Out:
# ['http://www.espncricinfo.com/wc1983/engine/match/65088.html',
#  'http://www.espncricinfo.com/wc1983/engine/match/65089.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65090.html']

# %%
scorecard_link.extend(scoreboard_link1) 
scorecard_link
# Out:
# ['http://content.cricinfo.com/wc1983/engine/match/65064.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65065.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65068.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65069.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65072.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65073.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65076.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65078.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65080.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65081.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65084.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65085.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65066.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65067.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65070.html',
# ...

# %%
scorecard_link
# Out:
# ['http://content.cricinfo.com/wc1983/engine/match/65064.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65065.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65068.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65069.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65072.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65073.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65076.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65078.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65080.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65081.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65084.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65085.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65066.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65067.html',
#  'http://content.cricinfo.com/wc1983/engine/match/65070.html',
# ...

# %%
scores=[]
for s in scorecard_link:
    res=requests.get(s,headers=headers)
    soup=BeautifulSoup(res.text,'lxml')
    score=soup.find_all('div',class_="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap")
    scores.append(score)
print(scores)
# Out:
# [[<div class="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-s ds-mr-0.5"></span><strong class="">322/6</strong></div>, <div class="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-s ds-mr-0.5">(59/60 ov, T:323) </span><strong class="">216</strong></div>], [<div class="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-s ds-mr-0.5"></span><strong class="">338/5</strong></div>, <div class="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-s ds-mr-0.5">(60 ov, T:339) </span><strong class="">288/9</strong></div>], [<div class="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-s ds-mr-0.5"></span><strong class="">333/9</strong></div>, <div class="ds-text-compact-m ds-text-typo ds-text-right ds-whitespace-nowrap"><span class="ds-text-compact-s ds-mr-0.5">(58/6
# ...

# %%
scores_new=[a for sublist in scores for a in sublist if a]
scores1=[]
for i in scores_new:
    n=i.find_all('strong',class_="")
    scores1.extend(n)
print(scores1)
# Out:
# [<strong class="">322/6</strong>, <strong class="">216</strong>, <strong class="">338/5</strong>, <strong class="">288/9</strong>, <strong class="">333/9</strong>, <strong class="">286</strong>, <strong class="">238/9</strong>, <strong class="">186</strong>, <strong class="">193/8</strong>, <strong class="">199/2</strong>, <strong class="">206</strong>, <strong class="">209/5</strong>, <strong class="">234</strong>, <strong class="">238/8</strong>, <strong class="">235/7</strong>, <strong class="">224</strong>, <strong class="">232/8</strong>, <strong class="">233/3</strong>, <strong class="">181</strong>, <strong class="">184/7</strong>, <strong class="">136</strong>, <strong class="">137/1</strong>, <strong class="">261/3</strong>, <strong class="">250</strong>, <strong class="">239/6</strong>, <strong class="">226/7</strong>, <strong class="">262/8</strong>, <strong class="">228</strong>, <strong class="">252/9</strong>, <strong class="">151</strong>, <strong class="">155</strong>
# ...

# %%
scores_end=[]
for i in scores1:
    scores_end.append(i.text)
print(scores_end)
# Out:
# ['322/6', '216', '338/5', '288/9', '333/9', '286', '238/9', '186', '193/8', '199/2', '206', '209/5', '234', '238/8', '235/7', '224', '232/8', '233/3', '181', '184/7', '136', '137/1', '261/3', '250', '239/6', '226/7', '262/8', '228', '252/9', '151', '155', '157/5', '320/9', '158', '217/7', '218/2', '282/9', '216', '272/7', '240', '273/6', '276/3', '266/8', '235', '247', '129', '171', '172/0', '213', '217/4', '184/8', '188/2', '183', '140']

# %%
scorebat_first=scores_end[::2]
scorebat_first
#
# Out:
# ['322/6',
#  '338/5',
#  '333/9',
#  '238/9',
#  '193/8',
#  '206',
#  '234',
#  '235/7',
#  '232/8',
#  '181',
#  '136',
#  '261/3',
#  '239/6',
#  '262/8',
#  '252/9',
#  '155',
#  '320/9',
#  '217/7',
#  '282/9',
#  '272/7',
#  '273/6',
#  '266/8',
#  '247',
#  '171',
#  '213',
#  '184/8',
#  '183']

# %%
scorebat_second=scores_end[1::2]
scorebat_second 
#
# Out:
# ['216',
#  '288/9',
#  '286',
#  '186',
#  '199/2',
#  '209/5',
#  '238/8',
#  '224',
#  '233/3',
#  '184/7',
#  '137/1',
#  '250',
#  '226/7',
#  '228',
#  '151',
#  '157/5',
#  '158',
#  '218/2',
#  '216',
#  '240',
#  '276/3',
#  '235',
#  '129',
#  '172/0',
#  '217/4',
#  '188/2',
#  '140']

# %%
mom=[]
for s in scorecard_link:
    res=requests.get(s,headers=headers)
    soup=BeautifulSoup(res.text,'lxml')
    mom1=soup.find_all('a',class_="ds-inline-flex ds-items-start ds-leading-none ds-max-w-full")
    mom.append(mom1)
print(mom)
# Out:
# [[], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], []]

# %%
res1=requests.get("https://www.espncricinfo.com/series/prudential-world-cup-1983-60832/england-vs-new-zealand-1st-match-65064/full-scorecard",headers=headers)
soup=BeautifulSoup(res1.text,'lxml')
mom1=soup.find_all('a',class_="ds-inline-flex ds-items-start ds-leading-none ds-max-w-full")
print(mom1)
# Out:
# []

# %%
res1=requests.get("https://www.espncricinfo.com/series/prudential-world-cup-1983-60832/england-vs-new-zealand-1st-match-65064/full-scorecard",headers=headers)
soup=BeautifulSoup(res1.text,'lxml')
mom1=soup.find_all('a')
print(mom1)
# Out:
# [<a class="ds-no-tap-higlight" href="/series/icc-men-s-cricket-world-cup-league-2-2023-24-2027-1420525/nepal-vs-scotland-44th-match-1450707/live-cricket-score"><div class="ds-text-compact-xxs"><div class="ds-w-[288px] ds-relative"><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-truncate"><span class=""></span><span class="ds-text-tight-xs ds-text-typo-mid2"><span class="ds-text-tight-xs ds-font-medium"><span>44th Match</span> • <!-- -->WCL 2<span class="ds-text-tight-xs ds-uppercase"> •  <!-- -->ODI</span></span> • <!-- --> <!-- -->Dallas</span></div><div class="ds-leading-[0]"></div></div><div class="ds-flex ds-justify-between ds-items-center"><div class="ds-flex ds-flex-col ds-mb-2 ds-mt-1 ds-space-y-1"><div class="ci-team-score ds-flex ds-justify-between ds-items-center ds-text-typo"><div class="ds-flex ds-items-center ds-min-w-0 ds-mr-1" title="Nepal"><img alt="Nepal Flag" class="ds-mr-2" height="20" src="https://wassets.hscicdn.com/static/images/lazyimage-
# ...

# %%
res1=requests.get("https://www.espncricinfo.com/series/prudential-world-cup-1983-60832/england-vs-new-zealand-1st-match-65064/full-scorecard",headers=headers)
soup=BeautifulSoup(res1.text,'lxml')
a_tag = soup.find('span',class_="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer")
a_tag.text
# Out:
# 'Allan Lamb'

# %%
res1=requests.get("https://www.espncricinfo.com/series/prudential-world-cup-1983-60832/pakistan-vs-sri-lanka-2nd-match-65065/full-scorecard",headers=headers)
soup=BeautifulSoup(res1.text,'lxml')
a_tag = soup.find('span',class_="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer")
a_tag.text
# Out:
# 'Mohsin Khan'

# %%
res1=requests.get("https://www.espncricinfo.com/series/prudential-world-cup-1983-60832/india-vs-zimbabwe-20th-match-65083/full-scorecard",headers=headers)
soup=BeautifulSoup(res1.text,'lxml')
a_tag = soup.find('span',class_="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer")
a_tag.text
# Out:
# 'Kapil Dev'

# %%
mom=[]
for s in scorecard_link:
    res=requests.get(s,headers=headers)
    soup=BeautifulSoup(res.text,'lxml')
    mom1=soup.find_all('span',class_="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer")
    mom.append(mom1)
print(mom)
# Out:
# [[<span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Allan Lamb</span>], [<span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Mohsin Khan</span>], [<span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">David Gower</span>], [<span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Abdul Qadir</span>], [<span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds
# ...

# %%
mom2=[a for sublist in mom for a in sublist if a]
print(mom2)
# Out:
# [<span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Allan Lamb</span>, <span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Mohsin Khan</span>, <span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">David Gower</span>, <span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Abdul Qadir</span>, <span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds
# ...

# %%
mom3=[a.text for a in mom2]
print(mom3)
# Out:
# ['Allan Lamb', 'Mohsin Khan', 'David Gower', 'Abdul Qadir', 'Zaheer Abbas', 'Richard Hadlee', 'Jeremy Coney', 'Abdul Qadir', 'Graeme Fowler', 'Ashantha de Mel', 'Bob Willis', 'Imran Khan', 'Duncan Fletcher', 'Yashpal Sharma', 'Winston Davis', 'Madan Lal', 'Trevor Chappell', 'Gordon Greenidge', 'Viv Richards', 'Dave Houghton', 'Viv Richards', 'Kapil Dev', 'Roger Binny', 'Faoud Bacchus', 'Mohinder Amarnath', 'Viv Richards', 'Mohinder Amarnath']

# %%
mom3
#
# Out:
# ['Allan Lamb',
#  'Mohsin Khan',
#  'David Gower',
#  'Abdul Qadir',
#  'Zaheer Abbas',
#  'Richard Hadlee',
#  'Jeremy Coney',
#  'Abdul Qadir',
#  'Graeme Fowler',
#  'Ashantha de Mel',
#  'Bob Willis',
#  'Imran Khan',
#  'Duncan Fletcher',
#  'Yashpal Sharma',
#  'Winston Davis',
#  'Madan Lal',
#  'Trevor Chappell',
#  'Gordon Greenidge',
#  'Viv Richards',
#  'Dave Houghton',
#  'Viv Richards',
#  'Kapil Dev',
#  'Roger Binny',
#  'Faoud Bacchus',
#  'Mohinder Amarnath',
#  'Viv Richards',
#  'Mohinder Amarnath']

# %%
<a class="ds-inline-flex ds-items-start ds-leading-none" href="/cricketers/allan-lamb-16178" title="Allan Lamb"><span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-cursor-pointer">Allan Lamb</span></a>

# %%
res1=requests.get("https://www.espncricinfo.com/series/prudential-world-cup-1983-60832/england-vs-new-zealand-1st-match-65064/full-scorecard",headers=headers)
soup=BeautifulSoup(res1.text,'lxml')
a_tag = soup.find_all('a', class_="ds-inline-flex ds-items-start ds-leading-none ds-max-w-full")

# Extract text within the <span> tag inside the <a> tag
an=[]
for a in a_tag:
    an1=a.span.get_text(strip=True)
    an.append(an1)
    

print(an)  # Output: Allan Lamb
# Out:
# []

# %%
import pandas as pd 
df1=pd.DataFrame({
    'Dates':date_of_match,
    'Ground':ground,
    'Location':location,
    'Team_That_BattedFirst':teambat_first,
    'Team_That_Batted_Second':teambat_second,
    'Score_Of_First_batting_team':scorebat_first,
    'Score_of_Second_batting_team':scorebat_second,
    'Man_of_match':mom3,
    'Results':results,
})
df1
# Out:
#             Dates         Ground               Location Team_That_BattedFirst  \
# 0    9 June 1983        The Oval                 London               England
# 1    9 June 1983      St Helen's                Swansea              Pakistan
# 2   11 June 1983   County Ground                Taunton               England
# 3   11 June 1983       Edgbaston             Birmingham           New Zealand
# 4   13 June 1983          Lord's                 London              Pakistan
# 5   13 June 1983   County Ground                Bristol             Sri Lanka
# 6   15 June 1983       Edgbaston             Birmingham               England
# 7   16 June 1983      Headingley                  Leeds              Pakistan
# 8   18 June 1983    Old Trafford             Manchester              Pakistan
# 9   18 June 1983   County Ground                  Derby           New Zealand
# 10  20 June 1983      Headingley                  Leeds             Sri Lanka
# ...

# %%
df1
# Out:
#             Dates         Ground               Location Team_That_BattedFirst  \
# 0    9 June 1983        The Oval                 London               England
# 1    9 June 1983      St Helen's                Swansea              Pakistan
# 2   11 June 1983   County Ground                Taunton               England
# 3   11 June 1983       Edgbaston             Birmingham           New Zealand
# 4   13 June 1983          Lord's                 London              Pakistan
# 5   13 June 1983   County Ground                Bristol             Sri Lanka
# 6   15 June 1983       Edgbaston             Birmingham               England
# 7   16 June 1983      Headingley                  Leeds              Pakistan
# 8   18 June 1983    Old Trafford             Manchester              Pakistan
# 9   18 June 1983   County Ground                  Derby           New Zealand
# 10  20 June 1983      Headingley                  Leeds             Sri Lanka
# ...

# %%
df1.to_csv("D:/1983Cricketworldcupdetails.csv",index=False)

# %%
from bs4 import BeautifulSoup

html = '''
<a href="/cricketers/allan-lamb-16178" title="Allan Lamb" class="ds-inline-flex ds-items-start ds-leading-none ds-max-w-full">
    <span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-whitespace-nowrap ds-overflow-hidden ds-text-ellipsis">
        Allan Lamb
    </span>
</a>
'''

# Parse the HTML content with BeautifulSoup
soup = BeautifulSoup(html, 'lxml')

# Find the specific <a> tag with the class name
a_tag = soup.find('a', class_="ds-inline-flex ds-items-start ds-leading-none ds-max-w-full")

# Extract text within the <span> tag inside the <a> tag
player_name = a_tag.span.get_text(strip=True)

print(player_name)  # Output: Allan Lamb
# Out:
# Allan Lamb

# %%
# <a href="/cricketers/allan-lamb-16178" title="Allan Lamb" class="ds-inline-flex ds-items-start ds-leading-none ds-max-w-full"><span class="ds-text-tight-m ds-font-medium ds-text-typo ds-underline ds-decoration-ui-stroke hover:ds-text-typo-primary hover:ds-decoration-ui-stroke-primary ds-block ds-whitespace-nowrap ds-overflow-hidden ds-text-ellipsis">Allan Lamb</span></a>

# %%
len(mom)
# Out:
# 27

# %%
len(scores_end)
# Out:
# 54

# %%
len(scorecard_link)
# Out:
# 27

# %%
a1=[9,11]
a2=[1,2,4]
a3=[42,41]
a1.extend(a2)
print(a1)
# Out:
# [9, 11, 1, 2, 4]

# %%
a1.extend(a3)
a1
# Out:
# [9, 11, 1, 2, 4, 42, 41]
